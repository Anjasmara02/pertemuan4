# %%
import seaborn as sns

# %%
df_penguin = sns.load_dataset('penguins')

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %%
print("jumlah secord yang punya nilai NULL:")
record_null = df_penguin.isna().sum()
print(record_null)
# Out:
# jumlah secord yang punya nilai NULL:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
df_penguin['bill_length_mm'].fillna(
    df_penguin["bill_depth_mm"].mean(),inplace=True
)
df_penguin
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen        39.10000           18.7              181.0
# 1    Adelie  Torgersen        39.50000           17.4              186.0
# 2    Adelie  Torgersen        40.30000           18.0              195.0
# 3    Adelie  Torgersen        17.15117            NaN                NaN
# 4    Adelie  Torgersen        36.70000           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe        17.15117            NaN                NaN
# 340  Gentoo     Biscoe        46.80000           14.3              215.0
# 341  Gentoo     Biscoe        50.40000           15.7              222.0
# 342  Gentoo     Biscoe        45.20000           14.8              212.0
# 343  Gentoo     Biscoe        49.90000           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# simplelputer

# %%
imputer = SimpleImputer(strategy='mean')
df_penguin["bill_depth_mm"] = imputer.fit_transform(
    df_penguin[["bill_depth_mm"]]
)
df_penguin
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen        39.10000       18.70000              181.0
# 1    Adelie  Torgersen        39.50000       17.40000              186.0
# 2    Adelie  Torgersen        40.30000       18.00000              195.0
# 3    Adelie  Torgersen        17.15117       17.15117                NaN
# 4    Adelie  Torgersen        36.70000       19.30000              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe        17.15117       17.15117                NaN
# 340  Gentoo     Biscoe        46.80000       14.30000              215.0
# 341  Gentoo     Biscoe        50.40000       15.70000              222.0
# 342  Gentoo     Biscoe        45.20000       14.80000              212.0
# 343  Gentoo     Biscoe        49.90000       16.10000              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df_penguin.penguin.iloc[1,:] =df_penguin.iloc[0,:]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\PC-01\Documents\pertemuan4anjas\pertemuan4\pertemuan4.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/PC-01/Documents/pertemuan4anjas/pertemuan4/pertemuan4.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> df_penguin.penguin.iloc[1,:] =df_penguin.iloc[0,:]
#
# File c:\Users\PC-01\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5907, in NDFrame.__getattr__(self, name)
#    5900 if (
#    5901     name not in self._internal_names_set
#    5902     and name not in self._metadata
#    5903     and name not in self._accessors
#    5904     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5905 ):
#    5906     return self[name]
# -> 5907 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'penguin'

# %% [markdown]
# duplicated

# %%
df_penguin.duplicated().sum()
# Out:
# 0

# %%
df_penguin.drop_duplicates(inplace=True)

# %%
df_penguin.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen        39.10000       18.70000              181.0
# 1  Adelie  Torgersen        39.50000       17.40000              186.0
# 2  Adelie  Torgersen        40.30000       18.00000              195.0
# 3  Adelie  Torgersen        17.15117       17.15117                NaN
# 4  Adelie  Torgersen        36.70000       19.30000              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
# normalisasi = minmaxscaler (bill_length_mm)
nrm = MinMaxScaler()
df_penguin["bill_length_mm"] = nrm.fit_transform(
    df_penguin[["bill_length_mm"]]
)

# %%
std =StandardScaler()
df_penguin["bill_depth_mm"] = std.fit_transform(
    df_penguin[["bill_depth_mm"]]
)

# %%
df_penguin['bill_depth_mm'].min()
# Out:
# -2.0604441268917233

# %%
print(df_penguin['bill_depth_mm'].mean())
print(df_penguin['bill_depth_mm'].std())
# Out:
# 4.1310624172098847e-16
# 1.0014566650110448

# %%
#ordinal encoder
df_penguin["sex"] = df_penguin["sex"].fillna("male")
df_penguin
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen        0.517066   7.877425e-01              181.0
# 1    Adelie  Torgersen        0.526489   1.265563e-01              186.0
# 2    Adelie  Torgersen        0.545335   4.317192e-01              195.0
# 3    Adelie  Torgersen        0.000000   1.806927e-15                NaN
# 4    Adelie  Torgersen        0.460527   1.092905e+00              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe        0.000000   1.806927e-15                NaN
# 340  Gentoo     Biscoe        0.698460  -1.450118e+00              215.0
# 341  Gentoo     Biscoe        0.783268  -7.380718e-01              222.0
# 342  Gentoo     Biscoe        0.660768  -1.195816e+00              212.0
# 343  Gentoo     Biscoe        0.771490  -5.346299e-01              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder,OneHotEncoder

# %%
#ordinal encoder
ordinal = OrdinalEncoder()

# %%
df_penguin['sex'] =  ordinal.fit_transform(df_penguin[['sex']])

# %%
df_penguin.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen        0.517066   7.877425e-01              181.0
# 1  Adelie  Torgersen        0.526489   1.265563e-01              186.0
# 2  Adelie  Torgersen        0.545335   4.317192e-01              195.0
# 3  Adelie  Torgersen        0.000000   1.806927e-15                NaN
# 4  Adelie  Torgersen        0.460527   1.092905e+00              193.0
#
#    body_mass_g  sex
# 0       3750.0  1.0
# 1       3800.0  0.0
# 2       3250.0  0.0
# 3          NaN  2.0
# 4       3450.0  0.0

# %%
onehot = OneHotEncoder(sparse=False)
species_enc = onehot.fit_transform(df_penguin[["species"]])
species_enc = pd.DataFrame(species_enc)

# %%
df_penguin["Adelie"] = species_enc[0]
df_penguin["Gento"] = species_enc[1]
df_penguin["Chistrap"] = species_enc[2]

# %%
df_penguin.drop()

# %% [markdown]
# Data Spiliting
